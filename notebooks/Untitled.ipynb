# %%
import os
import pandas as pd
df = pd.read_csv('../data/filtered/final_data.csv')

# %%
df.describe().T
# Out:
#                                      count         mean          std     min  \
# Air India                          10682.0     0.163921     0.370221     0.0
# GoAir                              10682.0     0.018161     0.133541     0.0
# IndiGo                             10682.0     0.192192     0.394042     0.0
# Jet Airways                        10682.0     0.360326     0.480117     0.0
# Jet Airways Business               10682.0     0.000562     0.023695     0.0
# Multiple carriers                  10682.0     0.111964     0.315337     0.0
# Multiple carriers Premium economy  10682.0     0.001217     0.034866     0.0
# SpiceJet                           10682.0     0.076577     0.265932     0.0
# Trujet                             10682.0     0.000094     0.009676     0.0
# Vistara                            10682.0     0.044842     0.206966     0.0
# Vistara Premium economy            10682.0     0.000281     0.016757     0.0
# ...
